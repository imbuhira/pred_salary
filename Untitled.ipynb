# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('cleaned_salary_data.csv')

# %%
df.head()
# Out:
#                                   Job Title               Salary Estimate  \
# 0                        Software Developer   $48K-$92K\n(Glassdoor est.)
# 1                        Software Developer  $67K-$125K\n(Glassdoor est.)
# 2     Software Developer (Loan Origination)   $35K-$67K\n(Glassdoor est.)
# 3            Engineering Software Developer   $38K-$82K\n(Glassdoor est.)
# 4  Full Stack Developer (core .net focused)   $49K-$90K\n(Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ImageSoft is a growing company centered around...     4.7
# 1  Job Description\n\nCACIs Business and Informat...     3.6
# 2  Software Developers are responsible for the an...     3.6
# 3  PURPOSE OF POSITION: To assist in the software...     3.1
# 4  Overview\n\n\nDatascan is a provider of wholes...     3.2
#
#                       Company Name        Location  Headquarters  \
# 0               ImageSoft Inc\n4.7  Southfield, MI            -1
# ...
